# %%
import pandas as pd

# %% [markdown]
# > url = "https://www.basketball-reference.com/teams/MIL/2023.html"

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc

# %%
#get_roster('MIL', 2022)

# %% [markdown]
# > YEAR
# 2000
# 2001
# 2002
# 2003
# 2004
# 2005
# 2006
# 2007
# 2008
# 2009
# 2010
# 2011
# 2012
# 2013
# 2014
# 2015
# 2016
# 2017
# 2018
# 2019
# 2020
# 2021
# 2022

# %%
#df_2000 = get_roster_stats('MIL',2000 , data_format='TOTALS', playoffs=False)
#df_2001 = get_roster_stats('MIL',2001 , data_format='TOTALS', playoffs=False)
#df_2002 = get_roster_stats('MIL',2002 , data_format='TOTALS', playoffs=False)
#df_2003 = get_roster_stats('MIL',2003 , data_format='TOTALS', playoffs=False)
#df_2004 = get_roster_stats('MIL',2004 , data_format='TOTALS', playoffs=False)
#df_2005 = get_roster_stats('MIL',2005 , data_format='TOTALS', playoffs=False)
#df_2006 = get_roster_stats('MIL',2006 , data_format='TOTALS', playoffs=False)
#df_2007 = get_roster_stats('MIL',2007 , data_format='TOTALS', playoffs=False)
#df_2008 = get_roster_stats('MIL',2008 , data_format='TOTALS', playoffs=False)
#df_2009 = get_roster_stats('MIL',2009 , data_format='TOTALS', playoffs=False)
#df_2010 = get_roster_stats('MIL',2010 , data_format='TOTALS', playoffs=False)
#df_2011 = get_roster_stats('MIL',2011 , data_format='TOTALS', playoffs=False)
#df_2012 = get_roster_stats('MIL',2012 , data_format='TOTALS', playoffs=False)
#df_2013 = get_roster_stats('MIL',2013 , data_format='TOTALS', playoffs=False)
#df_2014 = get_roster_stats('MIL',2014 , data_format='TOTALS', playoffs=False)
#df_2015 = get_roster_stats('MIL',2015 , data_format='TOTALS', playoffs=False)
#df_2016 = get_roster_stats('MIL',2016 , data_format='TOTALS', playoffs=False)
#df_2017 = get_roster_stats('MIL',2017 , data_format='TOTALS', playoffs=False)
#df_2018 = get_roster_stats('MIL',2018 , data_format='TOTALS', playoffs=False)
#df_2019 = get_roster_stats('MIL',2019 , data_format='TOTALS', playoffs=False)
#df_2020 = get_roster_stats('MIL',2020 , data_format='TOTALS', playoffs=False)
#df_2021 = get_roster_stats('MIL',2021 , data_format='TOTALS', playoffs=False)
df_2022 = get_roster_stats('MIL',2022 , data_format='TOTALS', playoffs=False)
#df_2023 = get_roster_stats('MIL',2023 , data_format='TOTALS', playoffs=False)

# %%
## PLAYOFFS

df_2022_reg = get_roster_stats('MIL',2022 , data_format='TOTALS', playoffs=False)
df_2022_playoffs = get_roster_stats('MIL',2022 , data_format='TOTALS', playoffs=True)

# %%
## CONCAT 

#df = pd.concat([df_2022_reg, df_2022_playoffs])

# %%
#df

# %%
#df.groupby(["PLAYER"]).sum()

# %%
#print(df.dtypes)

# %% [markdown]
# # Using enumerate()
# for i, val in enumerate(col):
#     print (i, ",",val)

# %% [markdown]
# # <b>2023

# %%
df_2023 = get_roster_stats('MIL',2023 , data_format='TOTALS', playoffs=False)
df = df_2023

# %%
# print(df.dtypes)
# CONVERT PTS 
df = df.astype({'AGE':'int','G':'int','GS':'int','MP':'int','FG':'int','FGA':'int','3P':'int','3PA':'int','2P':'int','2PA':'int','FT':'int','FTA':'int','ORB':'int','DRB':'int','TRB':'int','AST':'int','STL':'int','BLK':'int','TOV':'int','PF':'int','PTS':'int'})
#print(df.dtypes3P

# %%
#print(df.dtypes)

# %%
df.sort_values(by=['PTS'], ascending=False)
# Out:
#                     PLAYER POS  AGE TEAM  G  GS   MP  FG  FGA   FG%  ...  ORB  \
# 1    Giannis Antetokounmpo  PF   28  MIL  8   8  268  94  170  .553  ...   16
# 7             Jrue Holiday  PG   32  MIL  9   9  302  67  154  .435  ...   12
# 9              Brook Lopez   C   34  MIL  9   9  273  52  104  .500  ...   20
# 13            Bobby Portis  PF   27  MIL  9   1  232  50  108  .463  ...   26
# 0            Grayson Allen  SG   27  MIL  9   8  233  27   67  .403  ...    7
# 12            Jordan Nwora  SF   24  MIL  9   0  151  18   50  .360  ...    6
# 4             Jevon Carter  PG   27  MIL  9   9  215  18   50  .360  ...    6
# 6              George Hill  PG   36  MIL  9   0  192  15   34  .441  ...    3
# 11         Wesley Matthews  SG   36  MIL  9   0  135  10   31  .323  ...   12
# 3         MarJon Beauchamp  SF   22  MIL  6   1   72   9   26  .346  ...    4
# 8              Serge Ibaka  PF   33  MIL  7   0   74   8   18  .444  ...    4
# ...

# %%
df.sort_values(by=['3P%'], ascending=True)
# Out:
#                     PLAYER POS  AGE TEAM  G  GS   MP  FG  FGA   FG%  ...  ORB  \
# 3         MarJon Beauchamp  SF   22  MIL  6   1   72   9   26  .346  ...    4
# 1    Giannis Antetokounmpo  PF   28  MIL  8   8  268  94  170  .553  ...   16
# 6              George Hill  PG   36  MIL  9   0  192  15   34  .441  ...    3
# 11         Wesley Matthews  SG   36  MIL  9   0  135  10   31  .323  ...   12
# 13            Bobby Portis  PF   27  MIL  9   1  232  50  108  .463  ...   26
# 4             Jevon Carter  PG   27  MIL  9   9  215  18   50  .360  ...    6
# 12            Jordan Nwora  SF   24  MIL  9   0  151  18   50  .360  ...    6
# 7             Jrue Holiday  PG   32  MIL  9   9  302  67  154  .435  ...   12
# 9              Brook Lopez   C   34  MIL  9   9  273  52  104  .500  ...   20
# 0            Grayson Allen  SG   27  MIL  9   8  233  27   67  .403  ...    7
# 8              Serge Ibaka  PF   33  MIL  7   0   74   8   18  .444  ...    4
# ...

# %%
#list fields
for col in df.columns:
    print(col)
# Out:
# PLAYER
# POS
# AGE
# TEAM
# G
# GS
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# 2P
# 2PA
# 2P%
# eFG%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# SEASON

# %%
## iterate through each row and select respectively.
for index, row in df.iterrows():
    print(row["PLAYER"], row["PTS"])
# Out:
# Grayson Allen 90
# Giannis Antetokounmpo 261
# Thanasis Antetokounmpo 0
# MarJon Beauchamp 24
# Jevon Carter 51
# A.J. Green (TW) 0
# George Hill 47
# Jrue Holiday 180
# Serge Ibaka 24
# Brook Lopez 135
# Sandro Mamukelashvili 0
# Wesley Matthews 31
# Jordan Nwora 53
# Bobby Portis 120

# %%
df.sort_values(by=['PLAYER'], ascending=True)
# Out:
#                     PLAYER POS  AGE TEAM  G  GS   MP  FG  FGA   FG%  ...  ORB  \
# 5          A.J. Green (TW)  SG   23  MIL  1   0    2   0    0   NaN  ...    0
# 13            Bobby Portis  PF   27  MIL  9   1  232  50  108  .463  ...   26
# 9              Brook Lopez   C   34  MIL  9   9  273  52  104  .500  ...   20
# 6              George Hill  PG   36  MIL  9   0  192  15   34  .441  ...    3
# 1    Giannis Antetokounmpo  PF   28  MIL  8   8  268  94  170  .553  ...   16
# 0            Grayson Allen  SG   27  MIL  9   8  233  27   67  .403  ...    7
# 4             Jevon Carter  PG   27  MIL  9   9  215  18   50  .360  ...    6
# 12            Jordan Nwora  SF   24  MIL  9   0  151  18   50  .360  ...    6
# 7             Jrue Holiday  PG   32  MIL  9   9  302  67  154  .435  ...   12
# 3         MarJon Beauchamp  SF   22  MIL  6   1   72   9   26  .346  ...    4
# 10   Sandro Mamukelashvili   C   23  MIL  1   0    2   0    0   NaN  ...    0
# ...

# %%
#df.sort_values(by=['FG%'], ascending=False)

# %%
## iterate through each row and select respectively.
for index, row in df.iterrows():
    print(row["PLAYER"], row["PTS"], row["3PA"])
# Out:
# Grayson Allen 90 44
# Giannis Antetokounmpo 261 29
# Thanasis Antetokounmpo 0 0
# MarJon Beauchamp 24 15
# Jevon Carter 51 35
# A.J. Green (TW) 0 0
# George Hill 47 18
# Jrue Holiday 180 61
# Serge Ibaka 24 7
# Brook Lopez 135 57
# Sandro Mamukelashvili 0 0
# Wesley Matthews 31 25
# Jordan Nwora 53 26
# Bobby Portis 120 36

# %%
#print(df.dtypes)

# %%
##GROUP BY (after Concat)
#df2=df.sort_values('PLAYER',ascending=False).groupby('PTS')
