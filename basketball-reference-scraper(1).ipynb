# %% [markdown]
# # basketball-reference-scraper
# ### SOURCE
#  pip install basketball-reference-scraper
# > https://github.com/vishaalagartha/basketball_reference_scraper/blob/master/API.md

# %%
from basketball_reference_scraper.teams import get_roster, get_team_stats, get_opp_stats, get_roster_stats, get_team_misc

# %%
get_roster('MIL', 2022)
# Out:
#     NUMBER                  PLAYER POS HEIGHT  WEIGHT BIRTH_DATE NATIONALITY  \
# 0        7           Grayson Allen  SG    6-4     198 1995-10-08          US
# 1       34   Giannis Antetokounmpo  PF    7-0     242 1994-12-06          GR
# 2       43  Thanasis Antetokounmpo  SF    6-6     219 1992-07-18          GR
# 3       95         DeAndre' Bembry  SF    6-5     210 1994-07-04          US
# 4        5            Jevon Carter  PG    6-1     200 1995-09-14          US
# 5       24         Pat Connaughton  SF    6-5     209 1993-01-06          US
# 6       15        DeMarcus Cousins   C   6-10     270 1990-08-13          US
# 7       12         Javin DeLaurier   C   6-10     237 1998-04-07          US
# 8        0        Donte DiVincenzo  SG    6-4     203 1997-01-31          US
# 9       15             Jeff Dowtin  PG    6-3     185 1997-05-10          US
# 10      12       Langston Galloway  SG    6-1     200 1991-12-09          US
# ...

# %%
##TEAM
#get_team_stats('MIL', 2023, data_format='PER_GAME')
#get_team_stats('MIL', 2023, data_format='TOTAL')

# %%
##ROSTER
#get_roster_stats('MIL', 2023, data_format='PER_GAME', playoffs=False)
#get_roster_stats('MIL', 2023, data_format='TOTALS', playoffs=False)

# %%
df = get_roster_stats('MIL', 2022, data_format='TOTALS', playoffs=False)

# %%
print(df.dtypes)
# Out:
# PLAYER    object
# POS       object
# AGE       object
# TEAM      object
# G         object
# GS        object
# MP        object
# FG        object
# FGA       object
# FG%       object
# 3P        object
# 3PA       object
# 3P%       object
# 2P        object
# 2PA       object
# 2P%       object
# eFG%      object
# FT        object
# FTA       object
# FT%       object
# ORB       object
# DRB       object
# TRB       object
# AST       object
# STL       object
# BLK       object
# TOV       object
# PF        object
# PTS       object
# SEASON    object
# dtype: object

# %%
df.sort_values(by=['PTS'], ascending=False)
# Out:
#                     PLAYER POS AGE TEAM   G  GS    MP   FG   FGA   FG%  ...  \
# 28       Lindell Wigginton  PG  23  MIL  19   0   199   26    61  .426  ...
# 0            Grayson Allen  SG  26  MIL  66  61  1805  255   569  .448  ...
# 5          Pat Connaughton  SF  29  MIL  65  19  1691  227   496  .458  ...
# 3          DeAndre' Bembry  SF  27  MIL   8   0    77    3     8  .375  ...
# 23            Semi Ojeleye  PF  27  MIL  20   0   308   18    70  .257  ...
# 22            Jordan Nwora  SF  23  MIL  62  13  1185  186   462  .403  ...
# 25         Justin Robinson  PG  24  MIL  17   0   198   18    57  .316  ...
# 11             George Hill  PG  35  MIL  54  17  1253  118   275  .429  ...
# 26           Javonte Smart  PG  22  MIL  13   1   160   11    43  .256  ...
# 21             Greg Monroe   C  31  MIL   5   0    70   11    22  .500  ...
# 19         Wesley Matthews  SG  35  MIL  49  14  1002   87   220  .395  ...
# ...

# %%
# print(df.dtypes)
# CONVERT PTS 
df = df.astype({'Age':'int', 'G':'int', 'GS':'int','MP':'int','FG':'int','FGA':'int','3P':'int','ORB':'int','DRB':'int','TRB':'int','AST':'int','STL':'int','BLK':'int','TOV':'int','PF':'int','PTS':'int','3PA':'int','2P':'int','FT':'int','FTA':'int','2PA':'int'})
#print(df.dtypes)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-14-c0916203bfe6> in <module>
#       1 # print(df.dtypes)
#       2 # CONVERT PTS
# ----> 3 df = df.astype({'Age':'int', 'G':'int', 'GS':'int','MP':'int','FG':'int','FGA':'int','3P':'int','ORB':'int','DRB':'int','TRB':'int','AST':'int','STL':'int','BLK':'int','TOV':'int','PF':'int','PTS':'int','3PA':'int','2P':'int','FT':'int','FTA':'int','2PA':'int'})
#       4 #print(df.dtypes)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5780             for col_name in dtype.keys():
#    5781                 if col_name not in self:
# -> 5782                     raise KeyError(
#    5783                         "Only a column name can be used for the "
#    5784                         "key in a dtype mappings argument."
#
# ...
